# %% [markdown]
# # Sustainability Analysis

# %% [markdown]
# ### This project analyzes the data related to the United Nation's Global Sustainable Development Goal 12: "Ensure sustainable consumption and production patterns," in order to visualize trends and predict if the targets will be met by the goal target's deadlines of 2020 and 2030.
#
# Imported xlsx files and information on goal 12 are from the UN's SDG database website: https://unstats.un.org/sdgs/indicators/database with a total of 375,264 data observations related to the sustainability goal.
# However, due to incomplete data from some of the target datasets, we will be focus on the data from Target 12.2 and Target 12.4.

# %% [markdown]
# ## Import Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import seaborn as sns
import os

# %% [markdown]
# # Read in xlsx files related to UN's Goal of Sustainability

# %% [markdown]
# ## Electronic Waste Datasets

# %%
# 1st xlsx: electronic waste generated per capita (kg) 
# Goal 12, Target 12.4, Indicator 12.4.2
e_waste_pc = pd.read_excel('data/EN_EWT_GENPCAP.xlsx')
e_waste_pc.head(2)
# Out:
#    Goal  Target Indicator      SeriesCode  \
# 0    12    12.4    12.4.2  EN_EWT_GENPCAP
# 1    12    12.4    12.4.2  EN_EWT_GENPCAP
#
#                              SeriesDescription  GeoAreaCode  GeoAreaName  \
# 0  Electronic waste generated, per capita (Kg)            4  Afghanistan
# 1  Electronic waste generated, per capita (Kg)            2       Africa
#
#   Nature Reporting Type Units  ...      2010      2011      2012      2013  \
# 0      E              G    KG  ...  0.254903  0.297841  0.342332  0.385085
# 1      E              G    KG  ...  1.736518  1.882356  1.991023  2.095194
#
#        2014      2015      2016      2017      2018      2019
# 0  0.427947  0.468858  0.509681  0.549503  0.592546  0.630326
# 1  2.187254  2.262542  2.333871  2.384393  2.438595  2.486051
#
# [2 rows x 30 columns]

# %%
e_waste_pc.columns
# Out:
# Index(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription',
#        'GeoAreaCode', 'GeoAreaName', 'Nature', 'Reporting Type', 'Units',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019'],
#       dtype='object')

# %%
# Only keep necessary columns
e_waste_pc = e_waste_pc[['Target', 'Indicator', 'SeriesDescription', 'GeoAreaName', 'Units',
       '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
       '2018', '2019']]
e_waste_pc.head(2)
# Out:
#    Target Indicator                            SeriesDescription  GeoAreaName  \
# 0    12.4    12.4.2  Electronic waste generated, per capita (Kg)  Afghanistan
# 1    12.4    12.4.2  Electronic waste generated, per capita (Kg)       Africa
#
#   Units      2000      2001      2002      2003      2004  ...      2010  \
# 0    KG  0.064123  0.068659  0.074788  0.083986  0.094898  ...  0.254903
# 1    KG  0.850446  0.904585  0.961481  1.021856  1.091787  ...  1.736518
#
#        2011      2012      2013      2014      2015      2016      2017  \
# 0  0.297841  0.342332  0.385085  0.427947  0.468858  0.509681  0.549503
# 1  1.882356  1.991023  2.095194  2.187254  2.262542  2.333871  2.384393
#
#        2018      2019
# 0  0.592546  0.630326
# 1  2.438595  2.486051
#
# [2 rows x 25 columns]

# %%
# 2nd xlsx: electronic waste generated in metric unit Tonnes
# Goal 12, Target 12.4, Indicator 12.4.2
e_waste_total = pd.read_excel('data/EN_EWT_GENV.xlsx')
e_waste_total.head(2)
# Out:
#    Goal  Target Indicator   SeriesCode                    SeriesDescription  \
# 0    12    12.4    12.4.2  EN_EWT_GENV  Electronic waste generated (Tonnes)
# 1    12    12.4    12.4.2  EN_EWT_GENV  Electronic waste generated (Tonnes)
#
#    GeoAreaCode  GeoAreaName Nature Reporting Type   Units  ...          2010  \
# 0            4  Afghanistan      E              G  TONNES  ...  7.341974e+03
# 1            2       Africa      E              G  TONNES  ...  1.623176e+06
#
#            2011          2012          2013          2014          2015  \
# 0  8.848573e+03  1.050856e+04  1.221951e+04  1.401868e+04  1.581739e+04
# 1  1.783923e+06  1.943366e+06  2.097974e+06  2.244913e+06  2.382539e+06
#
#            2016          2017          2018          2019
# 0  1.766350e+04  1.952385e+04  2.134352e+04  2.301319e+04
# 1  2.515126e+06  2.649666e+06  2.780043e+06  2.905206e+06
#
# [2 rows x 30 columns]

# %%
# Only keep necessary columns
e_waste_total = e_waste_total[['Target', 'Indicator', 'SeriesDescription', 'GeoAreaName', 'Units',
       '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
       '2018', '2019']]
e_waste_total.head(2)
# Out:
#    Target Indicator                    SeriesDescription  GeoAreaName   Units  \
# 0    12.4    12.4.2  Electronic waste generated (Tonnes)  Afghanistan  TONNES
# 1    12.4    12.4.2  Electronic waste generated (Tonnes)       Africa  TONNES
#
#             2000           2001           2002           2003           2004  \
# 0    1310.912736    1462.783356    1660.511207    1941.416410    2279.356371
# 1  620085.609183  676266.228815  735815.811708  801704.357828  878039.257946
#
#    ...          2010          2011          2012          2013          2014  \
# 0  ...  7.341974e+03  8.848573e+03  1.050856e+04  1.221951e+04  1.401868e+04
# 1  ...  1.623176e+06  1.783923e+06  1.943366e+06  2.097974e+06  2.244913e+06
#
#            2015          2016          2017          2018          2019
# 0  1.581739e+04  1.766350e+04  1.952385e+04  2.134352e+04  2.301319e+04
# 1  2.382539e+06  2.515126e+06  2.649666e+06  2.780043e+06  2.905206e+06
#
# [2 rows x 25 columns]

# %% [markdown]
# ### Merge the electronic waste dataframes

# %%
# Merge the two dataframes 
merged_e_waste = pd.merge(e_waste_pc, e_waste_total, on="GeoAreaName")
merged_e_waste.head(2)
# Out:
#    Target_x Indicator_x                          SeriesDescription_x  \
# 0      12.4      12.4.2  Electronic waste generated, per capita (Kg)
# 1      12.4      12.4.2  Electronic waste generated, per capita (Kg)
#
#    GeoAreaName Units_x    2000_x    2001_x    2002_x    2003_x    2004_x  ...  \
# 0  Afghanistan      KG  0.064123  0.068659  0.074788  0.083986  0.094898  ...
# 1       Africa      KG  0.850446  0.904585  0.961481  1.021856  1.091787  ...
#
#          2010_y        2011_y        2012_y        2013_y        2014_y  \
# 0  7.341974e+03  8.848573e+03  1.050856e+04  1.221951e+04  1.401868e+04
# 1  1.623176e+06  1.783923e+06  1.943366e+06  2.097974e+06  2.244913e+06
#
#          2015_y        2016_y        2017_y        2018_y        2019_y
# 0  1.581739e+04  1.766350e+04  1.952385e+04  2.134352e+04  2.301319e+04
# 1  2.382539e+06  2.515126e+06  2.649666e+06  2.780043e+06  2.905206e+06
#
# [2 rows x 49 columns]

# %%
# # Visualize pairplots using seaborn
# sns.pairplot(merged_e_waste)

# %% [markdown]
# ## Electronic Waste Recycling Datasets

# %%
# 3rd xlsx: electronic waste recycling, per capita (kg) 
# Goal 12, Target 12.4, Indicator 12.4.2
e_recycling_pc = pd.read_excel('data/EN_EWT_RCYPCAP.xlsx')
e_recycling_pc.head(2)
# Out:
#    Goal  Target Indicator      SeriesCode  \
# 0    12    12.4    12.4.2  EN_EWT_RCYPCAP
# 1    12    12.4    12.4.2  EN_EWT_RCYPCAP
#
#                              SeriesDescription  GeoAreaCode  \
# 0  Electronic waste recycling, per capita (Kg)            8
# 1  Electronic waste recycling, per capita (Kg)           28
#
#            GeoAreaName Nature Reporting Type Units  2010  2011  2012  \
# 0              Albania      E              G    KG   NaN   NaN   NaN
# 1  Antigua and Barbuda      E              G    KG   NaN   NaN   NaN
#
#        2013       2014       2015       2016       2017       2018       2019
# 0  3.237495   4.242644   4.889079   5.103762   5.303011   5.477067   5.639709
# 1       NaN  11.883926  11.755779  12.078921  12.385940  12.666956  12.948181

# %%
e_recycling_pc.columns
# Out:
# Index(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription',
#        'GeoAreaCode', 'GeoAreaName', 'Nature', 'Reporting Type', 'Units',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019'],
#       dtype='object')

# %%
# Only keep necessary columns
e_recycling_pc = e_recycling_pc[['Target', 'Indicator', 'SeriesDescription', 'GeoAreaName', 'Units',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
       '2019']]
e_recycling_pc.head(2)
# Out:
#    Target Indicator                            SeriesDescription  \
# 0    12.4    12.4.2  Electronic waste recycling, per capita (Kg)
# 1    12.4    12.4.2  Electronic waste recycling, per capita (Kg)
#
#            GeoAreaName Units  2010  2011  2012      2013       2014  \
# 0              Albania    KG   NaN   NaN   NaN  3.237495   4.242644
# 1  Antigua and Barbuda    KG   NaN   NaN   NaN       NaN  11.883926
#
#         2015       2016       2017       2018       2019
# 0   4.889079   5.103762   5.303011   5.477067   5.639709
# 1  11.755779  12.078921  12.385940  12.666956  12.948181

# %%
# 4th xlsx: electronic waste recycling, in metric tonnes
# Goal 12, Target 12.4, Indicator 12.4.2
e_recycling_total = pd.read_excel('data/EN_EWT_RCYV.xlsx')
e_recycling_total.head(2)
# Out:
#    Goal  Target Indicator   SeriesCode                    SeriesDescription  \
# 0    12    12.4    12.4.2  EN_EWT_RCYV  Electronic waste recycling (Tonnes)
# 1    12    12.4    12.4.2  EN_EWT_RCYV  Electronic waste recycling (Tonnes)
#
#    GeoAreaCode          GeoAreaName Nature Reporting Type   Units  2010  2011  \
# 0            8              Albania      E              G  TONNES   NaN   NaN
# 1           28  Antigua and Barbuda      E              G  TONNES   NaN   NaN
#
#    2012    2013     2014     2015      2016      2017      2018      2019
# 0   NaN  9401.0  12288.0  14132.0  14731.64  15294.78  15788.93  16247.51
# 1   NaN     NaN   1100.0   1100.0   1141.70   1181.93   1219.60   1257.46

# %%
# Only keep necessary columns
e_recycling_total = e_recycling_total[['Target', 'Indicator', 'SeriesDescription', 'GeoAreaName', 'Units',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
       '2019']]
e_recycling_total.head(2)
# Out:
#    Target Indicator                    SeriesDescription          GeoAreaName  \
# 0    12.4    12.4.2  Electronic waste recycling (Tonnes)              Albania
# 1    12.4    12.4.2  Electronic waste recycling (Tonnes)  Antigua and Barbuda
#
#     Units  2010  2011  2012    2013     2014     2015      2016      2017  \
# 0  TONNES   NaN   NaN   NaN  9401.0  12288.0  14132.0  14731.64  15294.78
# 1  TONNES   NaN   NaN   NaN     NaN   1100.0   1100.0   1141.70   1181.93
#
#        2018      2019
# 0  15788.93  16247.51
# 1   1219.60   1257.46

# %% [markdown]
# ### Merge the electronic waste recycling dataframes

# %%
# Merge the two dataframes 
merged_e_recycling = pd.merge(e_recycling_pc, e_recycling_total, on="GeoAreaName")
merged_e_recycling.head(2)
# Out:
#    Target_x Indicator_x                          SeriesDescription_x  \
# 0      12.4      12.4.2  Electronic waste recycling, per capita (Kg)
# 1      12.4      12.4.2  Electronic waste recycling, per capita (Kg)
#
#            GeoAreaName Units_x  2010_x  2011_x  2012_x    2013_x     2014_x  \
# 0              Albania      KG     NaN     NaN     NaN  3.237495   4.242644
# 1  Antigua and Barbuda      KG     NaN     NaN     NaN       NaN  11.883926
#
#    ...  2010_y  2011_y  2012_y  2013_y   2014_y   2015_y    2016_y    2017_y  \
# 0  ...     NaN     NaN     NaN  9401.0  12288.0  14132.0  14731.64  15294.78
# 1  ...     NaN     NaN     NaN     NaN   1100.0   1100.0   1141.70   1181.93
#
#      2018_y    2019_y
# 0  15788.93  16247.51
# 1   1219.60   1257.46
#
# [2 rows x 29 columns]

# %%
# # Visualize pairplots using seaborn
# sns.pairplot(merged_e_recycling)

# %% [markdown]
# ## Hazardous Waste Datasets

# %%
# 5th xlsx: hazardous waste generated, per unit of GDP
# Goal 12, Target 12.4, Indicator 12.4.2
haz_waste_gen_GDP = pd.read_excel('data/EN_HAZ_GENGDP.xlsx')
haz_waste_gen_GDP.head(2)
# Out:
#    Goal  Target Indicator     SeriesCode  \
# 0    12    12.4    12.4.2  EN_HAZ_GENGDP
# 1    12    12.4    12.4.2  EN_HAZ_GENGDP
#
#                                    SeriesDescription  GeoAreaCode GeoAreaName  \
# 0  Hazardous waste generated, per unit of GDP (ki...           12     Algeria
# 1  Hazardous waste generated, per unit of GDP (ki...           20     Andorra
#
#   Nature Reporting Type           Units  ...      2007  2008  2010  2011  \
# 0      C              G  KG_PER_CON_USD  ...  0.002486   NaN   NaN   NaN
# 1      C              G  KG_PER_CON_USD  ...       NaN   NaN   NaN   NaN
#
#    2012      2013      2014      2015      2016      2017
# 0   NaN       NaN       NaN       NaN       NaN       NaN
# 1   NaN  0.000358  0.000746  0.000636  0.000671  0.000524
#
# [2 rows x 27 columns]

# %%
haz_waste_gen_GDP.columns
# Out:
# Index(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription',
#        'GeoAreaCode', 'GeoAreaName', 'Nature', 'Reporting Type', 'Units',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'],
#       dtype='object')

# %%
# Only keep necessary columns
haz_waste_gen_GDP = haz_waste_gen_GDP[['Target', 'Indicator', 'SeriesDescription', 'GeoAreaName', 'Units',
        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']]
haz_waste_gen_GDP.head(2)
# Out:
#    Target Indicator                                  SeriesDescription  \
# 0    12.4    12.4.2  Hazardous waste generated, per unit of GDP (ki...
# 1    12.4    12.4.2  Hazardous waste generated, per unit of GDP (ki...
#
#   GeoAreaName           Units  2000  2001  2002      2003  2004  ...  \
# 0     Algeria  KG_PER_CON_USD   NaN   NaN   NaN  0.002886   NaN  ...
# 1     Andorra  KG_PER_CON_USD   NaN   NaN   NaN       NaN   NaN  ...
#
#        2007  2008  2010  2011  2012      2013      2014      2015      2016  \
# 0  0.002486   NaN   NaN   NaN   NaN       NaN       NaN       NaN       NaN
# 1       NaN   NaN   NaN   NaN   NaN  0.000358  0.000746  0.000636  0.000671
#
#        2017
# 0       NaN
# 1  0.000524
#
# [2 rows x 22 columns]

# %%
# 6th xlsx: hazardous waste generated, in metric tonnes
# Goal 12, Target 12.4, Indicator 12.4.2
haz_waste_gen_total = pd.read_excel('data/EN_HAZ_GENV.xlsx')
haz_waste_gen_total.head(2)
# Out:
#    Goal  Target Indicator   SeriesCode                   SeriesDescription  \
# 0    12    12.4    12.4.2  EN_HAZ_GENV  Hazardous waste generated (Tonnes)
# 1    12    12.4    12.4.2  EN_HAZ_GENV  Hazardous waste generated (Tonnes)
#
#    GeoAreaCode GeoAreaName Nature Reporting Type   Units  ...  2008  2009  \
# 0           12     Algeria      C              G  TONNES  ...   NaN   NaN
# 1           20     Andorra      C              G  TONNES  ...   NaN   NaN
#
#    2010  2011  2012   2013    2014    2015        2016    2017
# 0   NaN   NaN   NaN    NaN     NaN     NaN         NaN     NaN
# 1   NaN   NaN   NaN  976.0  2081.0  1788.0  1923.40002  1527.5
#
# [2 rows x 28 columns]

# %%
# Only keep necessary columns
haz_waste_gen_total = haz_waste_gen_total[['Target', 'Indicator', 'SeriesDescription', 'GeoAreaName', 'Units',
        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']]
haz_waste_gen_total.head(2)
# Out:
#    Target Indicator                   SeriesDescription GeoAreaName   Units  \
# 0    12.4    12.4.2  Hazardous waste generated (Tonnes)     Algeria  TONNES
# 1    12.4    12.4.2  Hazardous waste generated (Tonnes)     Andorra  TONNES
#
#    2000  2001  2002      2003  2004  ...      2007  2008  2010  2011  2012  \
# 0   NaN   NaN   NaN  325000.0   NaN  ...  325100.0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN       NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN
#
#     2013    2014    2015        2016    2017
# 0    NaN     NaN     NaN         NaN     NaN
# 1  976.0  2081.0  1788.0  1923.40002  1527.5
#
# [2 rows x 22 columns]

# %% [markdown]
# ### Merge the two hazardous waste generated dataframes

# %%
# Merge the two dataframes 
merged_haz_waste_gen = pd.merge(haz_waste_gen_GDP, haz_waste_gen_total, on="GeoAreaName")
merged_haz_waste_gen.head(2)
# Out:
#    Target_x Indicator_x                                SeriesDescription_x  \
# 0      12.4      12.4.2  Hazardous waste generated, per unit of GDP (ki...
# 1      12.4      12.4.2  Hazardous waste generated, per unit of GDP (ki...
#
#   GeoAreaName         Units_x  2000_x  2001_x  2002_x    2003_x  2004_x  ...  \
# 0     Algeria  KG_PER_CON_USD     NaN     NaN     NaN  0.002886     NaN  ...
# 1     Andorra  KG_PER_CON_USD     NaN     NaN     NaN       NaN     NaN  ...
#
#      2007_y  2008_y  2010_y  2011_y  2012_y  2013_y  2014_y  2015_y  \
# 0  325100.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1       NaN     NaN     NaN     NaN     NaN   976.0  2081.0  1788.0
#
#        2016_y  2017_y
# 0         NaN     NaN
# 1  1923.40002  1527.5
#
# [2 rows x 43 columns]

# %%
# 7th xlsx: hazardous waste treated, by type of treatment
# Goal 12, Target 12.4, Indicator 12.4.2
haz_waste_treated = pd.read_excel('data/EN_HAZ_TREATV.xlsx')
haz_waste_treated.head(2)
# Out:
#    Goal  Target Indicator     SeriesCode  \
# 0    12    12.4    12.4.2  EN_HAZ_TREATV
# 1    12    12.4    12.4.2  EN_HAZ_TREATV
#
#                                    SeriesDescription  GeoAreaCode  \
# 0  Hazardous waste treated, by type of treatment ...           28
# 1  Hazardous waste treated, by type of treatment ...           51
#
#            GeoAreaName Nature Reporting Type Type of waste treatment  ...  \
# 0  Antigua and Barbuda      C              G                 LANDFIL  ...
# 1              Armenia      C              G                 INCINRT  ...
#
#           2008        2009        2010        2011        2012   2013    2014  \
# 0   100.860001   52.959999   23.059999  157.220001    7.940000   7.16    13.6
# 1  1359.000000  456.000000  300.000000   12.000000  167.399994  17.00  2379.0
#
#          2015        2016        2017
# 0   16.600000         NaN         NaN
# 1  289.700012  604.900024  582.799988
#
# [2 rows x 29 columns]

# %%
haz_waste_treated.columns
# Out:
# Index(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription',
#        'GeoAreaCode', 'GeoAreaName', 'Nature', 'Reporting Type',
#        'Type of waste treatment', 'Units', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017'],
#       dtype='object')

# %%
# Only keep necessary columns
haz_waste_treated = haz_waste_treated[['Target', 'Indicator', 'SeriesDescription', 'GeoAreaName', 'Type of waste treatment', 'Units',
        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']]
haz_waste_treated.head(2)
# Out:
#    Target Indicator                                  SeriesDescription  \
# 0    12.4    12.4.2  Hazardous waste treated, by type of treatment ...
# 1    12.4    12.4.2  Hazardous waste treated, by type of treatment ...
#
#            GeoAreaName Type of waste treatment   Units  2000  2001  2002  \
# 0  Antigua and Barbuda                 LANDFIL  TONNES   NaN   NaN   NaN
# 1              Armenia                 INCINRT  TONNES   NaN   NaN   NaN
#
#    2003  ...       2007         2008        2010        2011        2012  \
# 0   NaN  ...  51.759998   100.860001   23.059999  157.220001    7.940000
# 1   NaN  ...        NaN  1359.000000  300.000000   12.000000  167.399994
#
#     2013    2014        2015        2016        2017
# 0   7.16    13.6   16.600000         NaN         NaN
# 1  17.00  2379.0  289.700012  604.900024  582.799988
#
# [2 rows x 23 columns]

# %% [markdown]
# ### Merge the hazardous waste generated and hazardous waste treated datasets

# %%
merged_haz_waste_overall = pd.merge(merged_haz_waste_gen, haz_waste_treated, on="GeoAreaName")
merged_haz_waste_overall.head(2)
# Out:
#    Target_x Indicator_x                                SeriesDescription_x  \
# 0      12.4      12.4.2  Hazardous waste generated, per unit of GDP (ki...
# 1      12.4      12.4.2  Hazardous waste generated, per unit of GDP (ki...
#
#   GeoAreaName         Units_x    2000_x    2001_x    2002_x    2003_x  \
# 0     Armenia  KG_PER_CON_USD  0.097883  0.087922  0.076909  0.061407
# 1     Armenia  KG_PER_CON_USD  0.097883  0.087922  0.076909  0.061407
#
#      2004_x  ...      2007          2008          2010         2011  \
# 0  0.056768  ...       NaN    1359.00000     300.00000      12.0000
# 1  0.056768  ...  362275.0  433537.53125  432811.78125  457729.8125
#
#             2012         2013        2014           2015           2016  \
# 0     167.399994      17.0000    2379.000     289.700012     604.900024
# 1  460844.687500  574973.8125  571750.375  551020.062500  601917.375000
#
#             2017
# 0     582.799988
# 1  541012.375000
#
# [2 rows x 65 columns]

# %%
# # Visualize pairplots using seaborn
# sns.pairplot(merged_haz_waste_overall)

# %% [markdown]
# ## Domestic Material Consumption Datasets

# %%
# 8th xlsx: domestic material consumption per capita, by type of product
# Goal 12, Target 12.2, Indicator 12.2.2
dom_mat_consumption_pc = pd.read_excel('data/EN_MAT_DOMCMPC.xlsx')
dom_mat_consumption_pc.head(2)
# Out:
#    Goal  Target Indicator      SeriesCode  \
# 0    12    12.2    12.2.2  EN_MAT_DOMCMPC
# 1    12    12.2    12.2.2  EN_MAT_DOMCMPC
#
#                                    SeriesDescription  GeoAreaCode  \
# 0  Domestic material consumption per capita, by t...            4
# 1  Domestic material consumption per capita, by t...            4
#
#    GeoAreaName Nature Reporting Type Type of product  ...     2008     2009  \
# 0  Afghanistan      E              G             BIM  ...  1.72341  1.97509
# 1  Afghanistan      E              G             COL  ...  0.01271  0.01785
#
#       2010     2011     2012     2013     2014     2015     2016     2017
# 0  1.93652  1.82431  1.90564  1.83294  1.82012  1.80205  1.78902  1.77893
# 1  0.02517  0.02440  0.02443  0.04246  0.04633  0.04798  0.04962  0.05124
#
# [2 rows x 29 columns]

# %%
dom_mat_consumption_pc.columns
# Out:
# Index(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription',
#        'GeoAreaCode', 'GeoAreaName', 'Nature', 'Reporting Type',
#        'Type of product', 'Units', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017'],
#       dtype='object')

# %%
# Only keep necessary columns
dom_mat_consumption_pc = dom_mat_consumption_pc[['Target', 'Indicator', 'SeriesDescription', 'GeoAreaName', 'Type of product', 'Units',
        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']]
dom_mat_consumption_pc.head(2)
# Out:
#    Target Indicator                                  SeriesDescription  \
# 0    12.2    12.2.2  Domestic material consumption per capita, by t...
# 1    12.2    12.2.2  Domestic material consumption per capita, by t...
#
#    GeoAreaName Type of product   Units     2000     2001     2002     2003  \
# 0  Afghanistan             BIM  TONNES  2.26784  1.96185  2.07472  2.01228
# 1  Afghanistan             COL  TONNES  0.00005  0.00124  0.00096  0.00152
#
#    ...     2007     2008     2010     2011     2012     2013     2014  \
# 0  ...  1.79459  1.72341  1.93652  1.82431  1.90564  1.83294  1.82012
# 1  ...  0.00913  0.01271  0.02517  0.02440  0.02443  0.04246  0.04633
#
#       2015     2016     2017
# 0  1.80205  1.78902  1.77893
# 1  0.04798  0.04962  0.05124
#
# [2 rows x 23 columns]

# %%
# 9th xlsx: domestic material consumption per unit of GDP, by type of product
# Goal 12, Target 12.2, Indicator 12.2.2
dom_mat_consumption_GDP = pd.read_excel('data/EN_MAT_DOMCMPG.xlsx')
dom_mat_consumption_GDP.head(2)
# Out:
#    Goal  Target Indicator      SeriesCode  \
# 0    12    12.2    12.2.2  EN_MAT_DOMCMPG
# 1    12    12.2    12.2.2  EN_MAT_DOMCMPG
#
#                                    SeriesDescription  GeoAreaCode  \
# 0  Domestic material consumption per unit of GDP,...            4
# 1  Domestic material consumption per unit of GDP,...            4
#
#    GeoAreaName Nature Reporting Type Type of product  ...     2008     2009  \
# 0  Afghanistan      E              G             BIM  ...  3.54062  3.55151
# 1  Afghanistan      E              G             COL  ...  0.02612  0.03211
#
#       2010     2011     2012     2013     2014     2015     2016     2017
# 0  3.46922  3.10169  3.01790  2.81812  2.80302  2.91022  2.86592  2.85037
# 1  0.04509  0.04149  0.03869  0.06527  0.07135  0.07749  0.07949  0.08210
#
# [2 rows x 29 columns]

# %%
# Only keep necessary columns
dom_mat_consumption_GDP = dom_mat_consumption_GDP[['Target', 'Indicator', 'SeriesDescription', 'GeoAreaName', 'Type of product', 'Units',
        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']]
dom_mat_consumption_GDP.head(2)
# Out:
#    Target Indicator                                  SeriesDescription  \
# 0    12.2    12.2.2  Domestic material consumption per unit of GDP,...
# 1    12.2    12.2.2  Domestic material consumption per unit of GDP,...
#
#    GeoAreaName Type of product           Units     2000     2001     2002  \
# 0  Afghanistan             BIM  KG_PER_CON_USD  8.42728  8.06455  5.41873
# 1  Afghanistan             COL  KG_PER_CON_USD  0.00018  0.00510  0.00250
#
#       2003  ...     2007     2008     2010     2011     2012     2013  \
# 0  5.09579  ...  3.35689  3.54062  3.46922  3.10169  3.01790  2.81812
# 1  0.00384  ...  0.01708  0.02612  0.04509  0.04149  0.03869  0.06527
#
#       2014     2015     2016     2017
# 0  2.80302  2.91022  2.86592  2.85037
# 1  0.07135  0.07749  0.07949  0.08210
#
# [2 rows x 23 columns]

# %%
# 10th xlsx: domestic material consumption, by type of raw product
# Goal 12, Target 12.2, Indicator 12.2.2
dom_mat_consumption_total = pd.read_excel('data/EN_MAT_DOMCMPT.xlsx')
dom_mat_consumption_total.head(2)
# Out:
#    Goal  Target Indicator      SeriesCode  \
# 0    12    12.2    12.2.2  EN_MAT_DOMCMPT
# 1    12    12.2    12.2.2  EN_MAT_DOMCMPT
#
#                                    SeriesDescription  GeoAreaCode  \
# 0  Domestic material consumption, by type of raw ...            4
# 1  Domestic material consumption, by type of raw ...            4
#
#    GeoAreaName Nature Reporting Type Type of product  ...          2008  \
# 0  Afghanistan      E              G             BIM  ...  4.703888e+07
# 1  Afghanistan      E              G             COL  ...  3.470059e+05
#
#            2009          2010          2011          2012          2013  \
# 0  5.531095e+07  5.577784e+07  5.419777e+07  5.849743e+07  5.816242e+07
# 1  5.000084e+05  7.250122e+05  7.250122e+05  7.500126e+05  1.347192e+06
#
#            2014          2015          2016          2017
# 0  5.962340e+07  6.079494e+07  6.200024e+07  6.320554e+07
# 1  1.517746e+06  1.618705e+06  1.719664e+06  1.820623e+06
#
# [2 rows x 29 columns]

# %%
# Only keep necessary columns
dom_mat_consumption_total = dom_mat_consumption_total[['Target', 'Indicator', 'SeriesDescription', 'GeoAreaName', 'Type of product', 'Units',
        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']]
dom_mat_consumption_total.head(2)
# Out:
#    Target Indicator                                  SeriesDescription  \
# 0    12.2    12.2.2  Domestic material consumption, by type of raw ...
# 1    12.2    12.2.2  Domestic material consumption, by type of raw ...
#
#    GeoAreaName Type of product   Units          2000          2001  \
# 0  Afghanistan             BIM  TONNES  4.556943e+07  4.113297e+07
# 1  Afghanistan             COL  TONNES  1.000016e+03  2.600044e+04
#
#            2002          2003  ...          2007          2008          2010  \
# 0  4.560209e+07  4.641299e+07  ...  4.776615e+07  4.703888e+07  5.577784e+07
# 1  2.100036e+04  3.500059e+04  ...  2.430041e+05  3.470059e+05  7.250122e+05
#
#            2011          2012          2013          2014          2015  \
# 0  5.419777e+07  5.849743e+07  5.816242e+07  5.962340e+07  6.079494e+07
# 1  7.250122e+05  7.500126e+05  1.347192e+06  1.517746e+06  1.618705e+06
#
#            2016          2017
# 0  6.200024e+07  6.320554e+07
# 1  1.719664e+06  1.820623e+06
#
# [2 rows x 23 columns]

# %% [markdown]
# ### Merge the domestic material consumption dataframes

# %%
merged_dom_mat_consumption = pd.merge(dom_mat_consumption_pc, dom_mat_consumption_GDP, on="GeoAreaName")
merged_dom_mat_consumption.head(2)
# Out:
#    Target_x Indicator_x                                SeriesDescription_x  \
# 0      12.2      12.2.2  Domestic material consumption per capita, by t...
# 1      12.2      12.2.2  Domestic material consumption per capita, by t...
#
#    GeoAreaName Type of product_x Units_x   2000_x   2001_x   2002_x   2003_x  \
# 0  Afghanistan               BIM  TONNES  2.26784  1.96185  2.07472  2.01228
# 1  Afghanistan               BIM  TONNES  2.26784  1.96185  2.07472  2.01228
#
#    ...   2007_y   2008_y   2010_y   2011_y   2012_y   2013_y   2014_y  \
# 0  ...  3.35689  3.54062  3.46922  3.10169  3.01790  2.81812  2.80302
# 1  ...  0.01708  0.02612  0.04509  0.04149  0.03869  0.06527  0.07135
#
#     2015_y   2016_y   2017_y
# 0  2.91022  2.86592  2.85037
# 1  0.07749  0.07949  0.08210
#
# [2 rows x 45 columns]

# %%
merged_dom_mat_consumption_overall = pd.merge(dom_mat_consumption_total, merged_dom_mat_consumption, on="GeoAreaName")
merged_dom_mat_consumption_overall.head(2)
# Out:
#    Target Indicator                                  SeriesDescription  \
# 0    12.2    12.2.2  Domestic material consumption, by type of raw ...
# 1    12.2    12.2.2  Domestic material consumption, by type of raw ...
#
#    GeoAreaName Type of product   Units          2000          2001  \
# 0  Afghanistan             BIM  TONNES  4.556943e+07  4.113297e+07
# 1  Afghanistan             BIM  TONNES  4.556943e+07  4.113297e+07
#
#            2002          2003  ...   2007_y   2008_y   2010_y   2011_y  \
# 0  4.560209e+07  4.641299e+07  ...  3.35689  3.54062  3.46922  3.10169
# 1  4.560209e+07  4.641299e+07  ...  0.01708  0.02612  0.04509  0.04149
#
#     2012_y   2013_y   2014_y   2015_y   2016_y   2017_y
# 0  3.01790  2.81812  2.80302  2.91022  2.86592  2.85037
# 1  0.03869  0.06527  0.07135  0.07749  0.07949  0.08210
#
# [2 rows x 67 columns]

# %%
# # Visualize pairplots using seaborn
# sns.pairplot(merged_dom_mat_consumption_overall)

# %% [markdown]
# ### Now we have narrowed down the datasets for the different topics of sustainability:
# 1. Target 12.4 Electronic waste
# 2. Target 12.4 Electronic waste recycling
# 3. Target 12.4 Hazardous waste
# 4. Target 12.2 Domestic material consumption
#
# Merge these dataframes to perform analysis

# %%
# Merge the datasets related to Target 12.4 
merged_electronics = pd.merge(merged_e_waste, merged_e_recycling, on="GeoAreaName")
# merged_electronics.head(2)
merged_e_haz = pd.merge(merged_electronics, merged_haz_waste_overall, on="GeoAreaName")

# %%
# Target 12.4 data
merged_e_haz.corr()
# Out:
#               Target_x_x      2000_x_x      2001_x_x      2002_x_x  \
# Target_x_x  1.000000e+00  2.480215e-16  1.635238e-15  2.659223e-16
# 2000_x_x    2.480215e-16  1.000000e+00  9.999351e-01  9.997417e-01
# 2001_x_x    1.635238e-15  9.999351e-01  1.000000e+00  9.999179e-01
# 2002_x_x    2.659223e-16  9.997417e-01  9.999179e-01  1.000000e+00
# 2003_x_x   -7.395151e-16  9.993792e-01  9.996595e-01  9.998940e-01
# ...                  ...           ...           ...           ...
# 2013       -1.104773e-16  7.724378e-02  7.744689e-02  7.509243e-02
# 2014        1.522157e-16 -1.257999e-01 -1.252736e-01 -1.255984e-01
# 2015        2.397970e-17  8.553365e-02  8.602133e-02  8.406419e-02
# 2016       -1.189211e-16 -1.071335e-01 -1.063983e-01 -1.064531e-01
# 2017       -6.059134e-17  3.943998e-01  3.907727e-01  3.866531e-01
#
#                 2003_x_x      2004_x_x      2005_x_x      2006_x_x  \
# Target_x_x -7.395151e-16 -1.851084e-16  1.428931e-16  9.421214e-17
# 2000_x_x    9.993792e-01  9.988260e-01  9.980102e-01  9.972034e-01
# 2001_x_x    9.996595e-01  9.991962e-01  9.984730e-01  9.977386e-01
# 2002_x_x    9.998940e-01  9.995750e-01  9.989929e-01  9.983609e-01
# 2003_x_x    1.000000e+00  9.998788e-01  9.995044e-01  9.990087e-01
# ...                  ...           ...           ...           ...
# 2013        7.305368e-02  7.085104e-02  6.902435e-02  6.700423e-02
# 2014       -1.264493e-01 -1.271141e-01 -1.279735e-01 -1.289554e-01
# 2015        8.250200e-02  8.076261e-02  7.936371e-02  7.785314e-02
# 2016       -1.072300e-01 -1.078835e-01 -1.090156e-01 -1.103122e-01
# 2017        3.818228e-01  3.782991e-01  3.745585e-01  3.686297e-01
